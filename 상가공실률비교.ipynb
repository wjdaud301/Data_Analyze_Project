# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 소규모 상가 공실률

# %%
# !cd
# Out:
# C:\Users\의원1\git\2021_Multicampus_DataScience\Data-Visualization_project

# %%
ssg21 = pd.read_excel('../../[multi] 데이터 시각화 프로젝트/상권별_소규모_상가_공실률/상권별_소규모_상가_공실률_2021.xlsx')
ssg20 = pd.read_excel('../../[multi] 데이터 시각화 프로젝트/상권별_소규모_상가_공실률/상권별_소규모_상가_공실률_2020.xlsx')
ssg19 = pd.read_excel('../../[multi] 데이터 시각화 프로젝트/상권별_소규모_상가_공실률/상권별_소규모_상가_공실률_2019.xlsx')
ssg18 = pd.read_excel('../../[multi] 데이터 시각화 프로젝트/상권별_소규모_상가_공실률/상권별_소규모_상가_공실률_2018.xlsx')
ssg17 = pd.read_excel('../../[multi] 데이터 시각화 프로젝트/상권별_소규모_상가_공실률/상권별_소규모_상가_공실률_2017.xlsx')

ssg21_20 = [ssg20,ssg21]
ssg17_19 = [ssg17,ssg18,ssg19]

df21_20 = pd.DataFrame(ssg21[['상권별(1)','상권별(2)','상권별(3)']])
for ssg in ssg21_20:
    for i in ssg.columns:
        if i not in ['상권별(1)','상권별(2)','상권별(3)']:
            df21_20[i] = ssg[i]
            
            
df17_19 = pd.DataFrame(ssg17[['상권별(1)','상권별(2)']])
for ssg in ssg17_19:
    for i in ssg.columns:
        if i not in ['상권별(1)','상권별(2)']:
            df17_19[i] = ssg[i]

df21_20.head()
# Out:
# C:\ananconda\envs\multi\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#   상권별(1)    상권별(2) 상권별(3)  2020 1/4  2020 2/4  2020 3/4  2020 4/4  2021 1/4
# 0     전국        소계     소계       5.6       6.0       6.5       7.1       6.4
# 1     서울        소계     소계       4.0       4.2       5.7       7.5       6.5
# 2    NaN  소계(도심지역)     소계       1.9       3.3       8.4      10.5       8.5
# 3    NaN       NaN    광화문       0.0       4.3       4.3       4.3       4.2
# 4    NaN       NaN    남대문       5.3       5.3       5.3       9.9       8.1

# %%
df21_20['상권별(1)'].fillna(method='ffill',inplace=True)
df21_20['상권별(2)'].fillna(method='ffill',inplace=True)
df17_19['상권별(1)'].fillna(method='ffill',inplace=True)

# %%
df21_20.head()
# Out:
#   상권별(1)    상권별(2) 상권별(3)  2020 1/4  2020 2/4  2020 3/4  2020 4/4  2021 1/4
# 0     전국        소계     소계       5.6       6.0       6.5       7.1       6.4
# 1     서울        소계     소계       4.0       4.2       5.7       7.5       6.5
# 2     서울  소계(도심지역)     소계       1.9       3.3       8.4      10.5       8.5
# 3     서울  소계(도심지역)    광화문       0.0       4.3       4.3       4.3       4.2
# 4     서울  소계(도심지역)    남대문       5.3       5.3       5.3       9.9       8.1

# %%
df21_20.rename(columns = {'상권별(1)':'지역', '상권별(2)':'지역분류','상권별(3)' : '도심'}, inplace =True)
df17_19.rename(columns = {'상권별(1)':'지역', '상권별(2)':'도심'}, inplace =True)
df21_20.fillna(0.0, inplace = True)
df17_19.fillna(0.0, inplace = True)

# %%
df17_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   지역        192 non-null    object
#  1   도심        192 non-null    object
#  2   2017 1/4  192 non-null    float64
#  3   2017 2/4  192 non-null    float64
#  4   2017 3/4  192 non-null    float64
#  5   2017 4/4  192 non-null    float64
#  6   2018 1/4  192 non-null    float64
#  7   2018 2/4  192 non-null    float64
#  8   2018 3/4  192 non-null    float64
#  9   2018 4/4  192 non-null    float64
#  10  2019 1/4  192 non-null    float64
#  11  2019 2/4  192 non-null    float64
#  12  2019 3/4  192 non-null    float64
#  13  2019 4/4  192 non-null    float64
# dtypes: float64(12), object(2)
# memory usage: 21.1+ KB

# %%
df21_20.head()
# Out:
#    지역      지역분류   도심  2020 1/4  2020 2/4  2020 3/4  2020 4/4  2021 1/4
# 0  전국        소계   소계       5.6       6.0       6.5       7.1       6.4
# 1  서울        소계   소계       4.0       4.2       5.7       7.5       6.5
# 2  서울  소계(도심지역)   소계       1.9       3.3       8.4      10.5       8.5
# 3  서울  소계(도심지역)  광화문       0.0       4.3       4.3       4.3       4.2
# 4  서울  소계(도심지역)  남대문       5.3       5.3       5.3       9.9       8.1

# %%
# df21_20_서울 = df21_20.query("지역=='서울'")
# df17_19_서울 = df17_19.query("지역=='서울'")

# %%
df21_20.to_excel('상권별_소규모_상가_공실률(수정)_21~20.xlsx')
df17_19.to_excel('상권별_소규모_상가_공실률(수정)_17~19.xlsx')

# %% [markdown]
# ## 중대형 상가 공실률

# %%
ssg21 = pd.read_excel('상권별_중대형_상가_공실률_2021.xlsx')
ssg20 = pd.read_excel('상권별_중대형_상가_공실률_2020.xlsx')
ssg19 = pd.read_excel('상권별_중대형_상가_공실률_2019.xlsx')
ssg18 = pd.read_excel('상권별_중대형_상가_공실률_2018.xlsx')
ssg17 = pd.read_excel('상권별_중대형_상가_공실률_2017.xlsx')

ssg21_20 = [ssg20,ssg21]
ssg17_19 = [ssg17,ssg18,ssg19]

df21_20 = pd.DataFrame(ssg21[['상권별(1)','상권별(2)','상권별(3)']])
for ssg in ssg21_20:
    for i in ssg.columns:
        if i not in ['상권별(1)','상권별(2)','상권별(3)']:
            df21_20[i] = ssg[i]
            
            
df17_19 = pd.DataFrame(ssg17[['상권별(1)','상권별(2)']])
for ssg in ssg17_19:
    for i in ssg.columns:
        if i not in ['상권별(1)','상권별(2)']:
            df17_19[i] = ssg[i]
# Out:
# C:\ananconda\envs\multi\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df21_20['상권별(1)'].fillna(method='ffill',inplace=True)
df21_20['상권별(2)'].fillna(method='ffill',inplace=True)
df17_19['상권별(1)'].fillna(method='ffill',inplace=True)

df21_20.rename(columns = {'상권별(1)':'지역', '상권별(2)':'지역분류','상권별(3)' : '도심'}, inplace =True)
df17_19.rename(columns = {'상권별(1)':'지역', '상권별(2)':'도심'}, inplace =True)

df21_20.fillna(0.0, inplace = True)
df17_19.fillna(0.0, inplace = True)

# %%
df21_20_서울 = df21_20.query("지역=='서울'")
df17_19_서울 = df17_19.query("지역=='서울'")

# %%
df21_20_서울.to_excel('상권별_중대형_상가_공실률_21~20.xlsx')
df17_19_서울.to_excel('상권별_중대형_상가_공실률_17~19.xlsx')

# %% [markdown]
# ## 소규모 상가 임대료

# %%
ssi21 = pd.read_excel('../../[multi] 데이터 시각화 프로젝트/상권별_소규모_상가_임대료/상권별_소규모_상가_임대료_2021.xlsx')
ssi20 = pd.read_excel('../../[multi] 데이터 시각화 프로젝트/상권별_소규모_상가_임대료/상권별_소규모_상가_임대료_2020.xlsx')
ssi19 = pd.read_excel('../../[multi] 데이터 시각화 프로젝트/상권별_소규모_상가_임대료/상권별_소규모_상가_임대료_2019.xlsx')
ssi17_18 = pd.read_excel('../../[multi] 데이터 시각화 프로젝트/상권별_소규모_상가_임대료/상권별_소규모_상가_임대료_2017~18.xlsx')

ssi21_20 = [ssi20,ssi21]
ssi17_19 = [ssi17_18,ssi19]

df21_20 = pd.DataFrame(ssi21[['상권별(1)','상권별(2)','상권별(3)']])
for ssi in ssi21_20:
    for i in ssi.columns:
        if i not in ['상권별(1)','상권별(2)','상권별(3)']:
            df21_20[i] = ssi[i]
            
            
df17_19 = pd.DataFrame(ssi19[['상권별(1)','상권별(2)']])
for ssi in ssi17_19:
    for i in ssi.columns:
        if i not in ['상권별(1)','상권별(2)']:
            df17_19[i] = ssi[i]
# Out:
# C:\ananconda\envs\multi\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df21_20['상권별(1)'].fillna(method='ffill',inplace=True)
df21_20['상권별(2)'].fillna(method='ffill',inplace=True)
df17_19['상권별(1)'].fillna(method='ffill',inplace=True)

df21_20.rename(columns = {'상권별(1)':'지역', '상권별(2)':'지역분류','상권별(3)' : '도심'}, inplace =True)
df17_19.rename(columns = {'상권별(1)':'지역', '상권별(2)':'도심'}, inplace =True)

df21_20.fillna(0.0, inplace = True)
df17_19.fillna(0.0, inplace = True)

# %%
# df21_20_서울 = df21_20.query("지역=='서울'")
# df17_19_서울 = df17_19.query("지역=='서울'")

# %%
df21_20.to_excel('상권별_소규모_상가_임대료_21~20.xlsx')
df17_19.to_excel('상권별_소규모_상가_임대료_17~19.xlsx')

# %% [markdown]
# ## 중대형 상가 임대료

# %%
ssi21 = pd.read_excel('상권별_중대형_상가_임대료_2021.xlsx')
ssi20 = pd.read_excel('상권별_중대형_상가_임대료_2020.xlsx')
ssi19 = pd.read_excel('상권별_중대형_상가_임대료_2019.xlsx')
ssi17_18 = pd.read_excel('상권별_중대형_상가_임대료_2017~18.xlsx')

ssi21_20 = [ssi20,ssi21]
ssi17_19 = [ssi17_18,ssi19]

df21_20 = pd.DataFrame(ssi21[['상권별(1)','상권별(2)','상권별(3)']])
for ssi in ssi21_20:
    for i in ssi.columns:
        if i not in ['상권별(1)','상권별(2)','상권별(3)']:
            df21_20[i] = ssi[i]
            
            
df17_19 = pd.DataFrame(ssi19[['상권별(1)','상권별(2)']])
for ssi in ssi17_19:
    for i in ssi.columns:
        if i not in ['상권별(1)','상권별(2)']:
            df17_19[i] = ssi[i]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-c13792d9fd39> in <module>
# ----> 1 ssi21 = pd.read_excel('상권별_중대형_상가_임대료_2021.xlsx')
#       2 ssi20 = pd.read_excel('상권별_중대형_상가_임대료_2020.xlsx')
#       3 ssi19 = pd.read_excel('상권별_중대형_상가_임대료_2019.xlsx')
#       4 ssi17_18 = pd.read_excel('상권별_중대형_상가_임대료_2017~18.xlsx')
#       5
#
# C:\ananconda\envs\multi\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# C:\ananconda\envs\multi\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     334     if not isinstance(io, ExcelFile):
#     335         should_close = True
# --> 336         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     337     elif engine and engine != io.engine:
#     338         raise ValueError(
#
# C:\ananconda\envs\multi\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1070             else:
#    1071                 ext = inspect_excel_format(
# -> 1072                     content=path_or_buffer, storage_options=storage_options
#    1073                 )
#    1074
#
# C:\ananconda\envs\multi\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(path, content, storage_options)
#     948
#     949     with get_handle(
# --> 950         content_or_path, "rb", storage_options=storage_options, is_text=False
#     951     ) as handle:
#     952         stream = handle.handle
#
# C:\ananconda\envs\multi\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     649         else:
#     650             # Binary mode
# --> 651             handle = open(handle, ioargs.mode)
#     652         handles.append(handle)
#     653
#
# FileNotFoundError: [Errno 2] No such file or directory: '상권별_중대형_상가_임대료_2021.xlsx'

# %%
df21_20['상권별(1)'].fillna(method='ffill',inplace=True)
df21_20['상권별(2)'].fillna(method='ffill',inplace=True)
df17_19['상권별(1)'].fillna(method='ffill',inplace=True)

df21_20.rename(columns = {'상권별(1)':'지역', '상권별(2)':'지역분류','상권별(3)' : '도심'}, inplace =True)
df17_19.rename(columns = {'상권별(1)':'지역', '상권별(2)':'도심'}, inplace =True)

df21_20.fillna(0.0, inplace = True)
df17_19.fillna(0.0, inplace = True)

# %%
df21_20_서울 = df21_20.query("지역=='서울'")
df17_19_서울 = df17_19.query("지역=='서울'")

# %%
df21_20_서울.to_excel('상권별_중대형_상가_임대료_21~20.xlsx')
df17_19_서울.to_excel('상권별_중대형_상가_임대료_17~19.xlsx')

# %%
df21_20_서울.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-300fa21e1642> in <module>
# ----> 1 df21_20_서울.head()
#
# NameError: name 'df21_20_서울' is not defined

# %% [markdown]
# ## 소규모 상가 임대료 변환 20~21(천원/1m^2 -> 원/3.3m^2)

# %%
ssi21_20 = pd.read_excel('상권별_소규모_상가_임대료_21~20.xlsx')#,index_col='Unnamed: 0')

# %%
ssi21_20.drop('Unnamed: 0',axis=1, inplace=True)
def convert(x):
    return x * 3.3 * 1000

tmp = ssi21_20.iloc[:,3:].apply(convert)
tmp = tmp.astype(int)
ssi21_20.drop(ssi21_20.iloc[:,3:],axis=1,inplace=True)

# %%
ssi21_20 = pd.merge(ssi21_20, tmp,
       left_index=True, right_index=True,how='left')

# %%
ssi21_20.to_excel('상권별_소규모_상가_임대료_21~20(변환).xlsx')

# %% [markdown]
# ## 소규모 상가 임대료 변환 17~19(천원/1m^2 -> 원/3.3m^2)

# %%
ssi17_19 = pd.read_excel('상권별_소규모_상가_임대료_17~19.xlsx')#,index_col='Unnamed: 0')

# %%
ssi17_19.head()
# Out:
#    Unnamed: 0  지역        도심  2017 1/4  2017 2/4  2017 3/4  2017 4/4  2018 1/4  \
# 0           0  전국        소계      21.4      21.4      21.4      21.4      20.9
# 1           1  서울        소계      52.3      52.4      52.3      52.4      52.5
# 2           2  서울  소계(도심지역)      69.2      69.3      69.3      69.3      68.7
# 3           3  서울       광화문      65.9      65.9      65.8      66.0      66.1
# 4           4  서울       남대문      43.1      43.1      43.1      43.1      42.8
#
#    2018 2/4  2018 3/4  2018 4/4  2019 1/4  2019 2/4  2019 3/4  2019 4/4
# 0      20.9      20.9      20.8      20.4      20.4      20.4      20.3
# 1      52.3      52.5      52.5      54.6      54.7      54.7      54.7
# 2      68.8      69.0      69.1      76.6      76.5      76.7      76.7
# 3      66.8      67.0      67.6      95.0      95.0      95.0      95.1
# 4      42.7      42.7      42.7      75.7      75.4      75.4      75.4

# %%
ssi17_19.drop('Unnamed: 0',axis=1, inplace=True)
def convert(x):
    return x * 3.3 * 1000

tmp = ssi17_19.iloc[:,2:].apply(convert)
tmp = tmp.astype(int)
ssi17_19.drop(ssi17_19.iloc[:,2:],axis=1,inplace=True)

# %%
ssi17_19 = pd.merge(ssi17_19, tmp,
       left_index=True, right_index=True,how='left')

# %%
ssi17_19.head()
# Out:
#    지역        도심  2017 1/4  2017 2/4  2017 3/4  2017 4/4  2018 1/4  2018 2/4  \
# 0  전국        소계     70619     70619     70619     70619     68969     68969
# 1  서울        소계    172589    172920    172589    172920    173250    172589
# 2  서울  소계(도심지역)    228359    228689    228689    228689    226710    227040
# 3  서울       광화문    217470    217470    217140    217799    218129    220439
# 4  서울       남대문    142230    142230    142230    142230    141239    140910
#
#    2018 3/4  2018 4/4  2019 1/4  2019 2/4  2019 3/4  2019 4/4
# 0     68969     68640     67320     67320     67320     66990
# 1    173250    173250    180180    180510    180510    180510
# 2    227700    228029    252779    252450    253109    253109
# 3    221100    223079    313500    313500    313500    313830
# 4    140910    140910    249810    248820    248820    248820

# %%
ssi17_19.to_excel('상권별_소규모_상가_임대료_17~19(변환).xlsx')

# %% [markdown]
# ## 중대형 상가 임대료 변환 21~20(천원/1m^2 -> 원/3.3m^2)

# %%
Ssi21_20 = pd.read_excel('상권별_중대형_상가_임대료_21~20.xlsx')#,index_col='Unnamed: 0')

# %%
Ssi21_20.drop('Unnamed: 0',axis=1, inplace=True)
def convert(x):
    return x * 3.3 * 1000

tmp = Ssi21_20.iloc[:,3:].apply(convert)
tmp = tmp.astype(int)
Ssi21_20.drop(Ssi21_20.iloc[:,3:],axis=1,inplace=True)

# %%
Ssi21_20 = pd.merge(Ssi21_20, tmp,
       left_index=True, right_index=True,how='left')

# %%
Ssi21_20.head()
# Out:
#    지역      지역분류   도심  2020 1/4  2020 2/4  2020 3/4  2020 4/4  2021 1/4
# 0  서울        소계   소계    182489    181829    180510    178860    172589
# 1  서울  소계(도심지역)   소계    321420    317789    314820    306239    291060
# 2  서울  소계(도심지역)  광화문    269610    269280    259380    257399    258720
# 3  서울  소계(도심지역)  남대문    271920    270599    268289    266310    255420
# 4  서울  소계(도심지역)  동대문    135960    135960    138600    138269    148829

# %%
Ssi21_20.to_excel('상권별_중대형_상가_임대료_21~20(변환).xlsx')

# %% [markdown]
# ## 중대형 상가 임대료 변환 17~19(천원/1m^2 -> 원/3.3m^2)

# %%
Ssi17_19 = pd.read_excel('상권별_중대형_상가_임대료_17~19.xlsx')#,index_col='Unnamed: 0')

# %%
Ssi17_19.drop('Unnamed: 0',axis=1, inplace=True)
def convert(x):
    return x * 3.3 * 1000

tmp = Ssi17_19.iloc[:,2:].apply(convert)
tmp = tmp.astype(int)
Ssi17_19.drop(Ssi17_19.iloc[:,2:],axis=1,inplace=True)

# %%
Ssi17_19 = pd.merge(Ssi17_19, tmp,
       left_index=True, right_index=True,how='left')

# %%
Ssi17_19.head()
# Out:
#    지역        도심  2017 1/4  2017 2/4  2017 3/4  2017 4/4  2018 1/4  2018 2/4  \
# 0  서울        소계    195359    195359    195359    195689    193380    193380
# 1  서울  소계(도심지역)    317460    316470    313170    313170    313500    314820
# 2  서울       광화문    230010    228689    228359    228359    228029    230010
# 3  서울       남대문    120449    120449    120449    120449    120449    120119
# 4  서울       동대문    914759    914759    892319    892319    892319    896609
#
#    2018 3/4  2018 4/4  2019 1/4  2019 2/4  2019 3/4  2019 4/4
# 0    193049    192060    191070    191399    192060    192060
# 1    314820    309210    329670    331320    331979    331979
# 2    231000    231329    287760    287760    287760    287760
# 3    120119    120119    290400    291060    298320    298320
# 4    890009    850080    120780    121110    121439    121110

# %%
Ssi17_19.to_excel('상권별_중대형_상가_임대료_17~19(변환).xlsx')

# %% [markdown]
# ## 순영업수익 년도별 합치기

# %%
ssc21 = pd.read_excel('상권별_소규모_상가_순영업소득/상권별_소규모_상가_순영업소득_2021.xlsx',header=None)
ssc20 = pd.read_excel('상권별_소규모_상가_순영업소득/상권별_소규모_상가_순영업소득_2020.xlsx',header=None)
ssc19 = pd.read_excel('상권별_소규모_상가_순영업소득/상권별_소규모_상가_순영업소득_2019.xlsx',header=None)
ssc17_18 = pd.read_excel('상권별_소규모_상가_순영업소득/상권별_소규모_상가_순영업소득_2017~18.xlsx',header=None)
# Out:
# C:\ananconda\envs\multi\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
li = [ssc17_18,ssc19,ssc20,ssc21]
for ssc in li:
    ssc.columns = ssc.iloc[1]
    ssc.drop(index=[1],axis=0,inplace=True)
    ssc.reset_index(inplace=True)
    ssc.drop(['index'],axis=1,inplace=True)

# %%
ssc21.head(3)
# Out:
# 1  상권별(1)  상권별(2)  상권별(3)  임대수입 (%)  기타수입 (%)  영업경비 (%) 순영업소득 (%) 순영업소득 (천원/㎡)
# 0  상권별(1)  상권별(2)  상권별(3)  2021 1/4  2021 1/4  2021 1/4  2021 1/4     2021 1/4
# 1      전국      소계      소계      99.7       0.3      11.2      88.8         37.7
# 2      서울      소계      소계      99.3       0.7      10.1      89.9         94.6

# %%
def extraction_20_21(x):
    return x[["상권별(1)","상권별(2)","상권별(3)","순영업소득 (천원/㎡)"]]

def extraction_17_19(x):
    return x[["상권별(1)","상권별(2)","순영업소득 (천원/㎡)"]]

# ssc20 = ssc20.apply(extraction_20_21,axis=1)
# ssc20.columns = ssc20.iloc[0]
# ssc20.drop(index=0,axis=0,inplace=True)
    
# ssc21_20 = [ssc20,ssc21]
# ssc17_19 = [ssc17_18,ssc19]


ssc21 = ssc21.apply(extraction_20_21,axis=1)
ssc21.columns = ssc21.iloc[0]
ssc21.drop(index=0,axis=0,inplace=True)

ssc20 = ssc20.apply(extraction_20_21,axis=1)
ssc20.columns = ssc20.iloc[0]
ssc20.drop(index=0,axis=0,inplace=True)

ssc19 = ssc19.apply(extraction_17_19,axis=1)
ssc19.columns = ssc19.iloc[0]
ssc19.drop(index=0,axis=0,inplace=True)

ssc17_18 = ssc17_18.apply(extraction_17_19,axis=1)
ssc17_18.columns = ssc17_18.iloc[0]
ssc17_18.drop(index=0,axis=0,inplace=True)

# %%
ssc19.head(3)
# Out:
# 0 상권별(1)    상권별(2) 2019 1/4 2019 2/4 2019 3/4 2019 4/4
# 1     전국        소계     42.3     42.2     32.2     41.6
# 2     서울        소계    111.6    111.9     77.8    111.4
# 3    NaN  소계(도심지역)    161.1    162.2    111.5    161.1

# %%
ssc21_20 = [ssc20,ssc21]
ssc17_19 = [ssc17_18,ssc19]

df21_20 = pd.DataFrame(ssc21[['상권별(1)','상권별(2)','상권별(3)']])
for ssc in ssc21_20:
    for i in ssc.columns:
        if i not in ['상권별(1)','상권별(2)','상권별(3)']:
            df21_20[i] = ssc[i]
            
            
df17_19 = pd.DataFrame(ssc19[['상권별(1)','상권별(2)']])
for ssc in ssc17_19:
    for i in ssc.columns:
        if i not in ['상권별(1)','상권별(2)']:
            df17_19[i] = ssc[i]

# %%
df21_20['상권별(1)'].fillna(method='ffill',inplace=True)
df21_20['상권별(2)'].fillna(method='ffill',inplace=True)
df17_19['상권별(1)'].fillna(method='ffill',inplace=True)

df21_20.rename(columns = {'상권별(1)':'지역', '상권별(2)':'지역분류','상권별(3)' : '도심'}, inplace =True)
df17_19.rename(columns = {'상권별(1)':'지역', '상권별(2)':'도심'}, inplace =True)

df21_20.fillna(0.0, inplace = True)
df17_19.fillna(0.0, inplace = True)

# %%
df21_20.head(3)
# Out:
# 0  지역      지역분류  도심  2020 1/4  2020 2/4  2020 3/4  2020 4/4  2021 1/4
# 1  전국        소계  소계      40.7      40.3      29.5      38.4      37.7
# 2  서울        소계  소계     102.2     101.4      62.7      93.5      94.6
# 3  서울  소계(도심지역)  소계     158.9     157.0      88.4     131.7     132.1

# %%
df17_19.head(3)
# Out:
# 0  지역        도심  2017 1/4  2017 2/4  2017 3/4  2017 4/4  2018 1/4  2018 2/4  \
# 1  전국        소계      45.0      44.9      36.6      44.5      42.8      42.7
# 2  서울        소계     109.5     109.8      83.8     108.7     107.2     108.0
# 3  서울  소계(도심지역)     148.2     147.4     116.1     144.0     140.8     144.7
#
# 0  2018 3/4  2018 4/4  2019 1/4  2019 2/4  2019 3/4  2019 4/4
# 1      33.9      42.9      42.3      42.2      32.2      41.6
# 2      80.2     109.6     111.6     111.9      77.8     111.4
# 3     102.0     146.2     161.1     162.2     111.5     161.1

# %%
def convert20_21(x):
    return x * 3.3 * 1000

tmp1 = df21_20.iloc[:,3:].apply(convert20_21)
tmp1 = tmp1.astype(int)
df21_20.drop(df21_20.iloc[:,3:],axis=1,inplace=True)

# %%
def convert17_19(x):
    return x * 3.3 * 1000

tmp2 = df17_19.iloc[:,2:].apply(convert17_19)
tmp2 = tmp2.astype(int)
df17_19.drop(df17_19.iloc[:,2:],axis=1,inplace=True)

# %%
df21_20 = pd.merge(df21_20, tmp1,
       left_index=True, right_index=True,how='left')

# %%
df17_19 = pd.merge(df17_19, tmp2,
       left_index=True, right_index=True,how='left')

# %%
df21_20.head(3)
# Out:
# 0  지역      지역분류  도심  2020 1/4  2020 2/4  2020 3/4  2020 4/4  2021 1/4
# 1  전국        소계  소계    134310    132989     97350    126719    124410
# 2  서울        소계  소계    337260    334620    206910    308550    312179
# 3  서울  소계(도심지역)  소계    524370    518100    291720    434609    435929

# %%
df17_19.head(3)
# Out:
# 0  지역        도심  2017 1/4  2017 2/4  2017 3/4  2017 4/4  2018 1/4  2018 2/4  \
# 1  전국        소계    148500    148170    120780    146850    141239    140910
# 2  서울        소계    361349    362340    276539    358710    353760    356400
# 3  서울  소계(도심지역)    489059    486420    383129    475200    464640    477509
#
# 0  2018 3/4  2018 4/4  2019 1/4  2019 2/4  2019 3/4  2019 4/4
# 1    111869    141570    139589    139260    106260    137280
# 2    264659    361679    368280    369270    256739    367620
# 3    336599    482459    531630    535259    367950    531630

# %%
df21_20.to_excel('상권별_소규모_상가_순영업소득_21~20.xlsx')
df17_19.to_excel('상권별_소규모_상가_순영업소득_17~19.xlsx')
