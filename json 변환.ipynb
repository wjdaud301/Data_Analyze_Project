# %%
from urllib.parse import urlencode, unquote
# import urllib.request
import json
import requests
import pandas as pd
import numpy as np

url = "http://apis.data.go.kr/B553077/api/open/sdsc/storeListInDong"
api_key = 'LXAFnythUXqok0ZsUst9WH4yRP3a9z7KjuM8P8KlKb4HSJIq%2Bbvt%2F4mTNmHL%2FyioJMw65V5T0ZWJaj2kl5HOEA%3D%3D'

# url뒤에 auery붙이기
queryString = '?' + urlencode(
    {
    "ServiceKey" : unquote(api_key),
    "divId" : "ctprvnCd",
    "key" : 11,
    "type" : "json" # json형태로 가져오기
    }
)

queryURL = url + queryString

# storeListInDong = json.loads(response.text)
# r_response = storeListInDong.get("response")
# r_body = r_response.get("body")

# %%
## (방법 1)
response = requests.get(queryURL)
# print(response.text)

## (방법 2)
# response = urllib.request.urlopen(queryURL)
# json_str = response.read().decode('utf-8')
# print(json_str)

## (json을 읽어와서 dataframe으로 만들기)
json_object = json.loads(response.text)
body = [json_object['body']['items']]
df=pd.DataFrame(body)
df

## (json으로 저장)
# with open("C:/Users/의원1/git/[multi] 데이터 시각화 프로젝트/NO_16.json",'w', encoding='cp949') as f:
#     json.dump(response.text, f)
# Out:
#                                                   0   \
# 0  {'bizesId': '10004623', 'bizesNm': '이철헤어커커', '...
#
#                                                   1   \
# 0  {'bizesId': '10004646', 'bizesNm': '이철헤어커커', '...
#
#                                                   2   \
# 0  {'bizesId': '10025887', 'bizesNm': '잠뱅이', 'brc...
#
#                                                   3   \
# 0  {'bizesId': '10030788', 'bizesNm': '장안순대국밥', '...
#
#                                                   4   \
# 0  {'bizesId': '10031349', 'bizesNm': '장어야', 'brc...
#
#                                                   5   \
# 0  {'bizesId': '10031436', 'bizesNm': '장어천국', 'br...
#
#                                                   6   \
# 0  {'bizesId': '10034303', 'bizesNm': '재건공조', 'br...
#
#                                                   7   \
# 0  {'bizesId': '10038561', 'bizesNm': '전자랜드', 'br...
#
#                                                   8   \
# ...
